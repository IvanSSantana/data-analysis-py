# %%
import pandas as pd

# %%
vendas_db_caminho = 'db\\Base_analitica_vendas.xlsx'

# %%
vendas_db = pd.read_excel(vendas_db_caminho, sheet_name='Base')

# %% [markdown]
# Exibindo dados como de planilhas (topo, inferior e aleatório, respectivamente)

# %%
# vendas_db.head(5)
# vendas_db.tail(5)
vendas_db.sample(5)
# Out:
#       DATAEMISSAO  CODIGOCLIENTE               DESCRICAOCLIENTE  \
# 36095  2026-02-25       10004236  ATACADISTA SELEÇÃO DE BEBIDAS
# 22001  2026-02-16       10004004  CENTRAL DE NUTRIÇÃO E BEBIDAS
# 3035   2026-02-03       10000964    LOGÍSTICA ESSENCIAL BEBIDAS
# 39749  2026-02-28       10004219     SUPRIMENTOS MASTER BEBIDAS
# 21887  2026-02-16       10004002    COMERCIAL MUNDO DAS BEBIDAS
#
#        CODIGOGRUPOPRODUTO             DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 36095            90013022  Insumos para Produção de Bebidas       10026538
# 22001            90013014            Sucos Naturais Premium       10008337
# 3035             90013094       Bebidas Energéticas Premium       10020283
# 39749            90013094       Bebidas Energéticas Premium       10020281
# 21887            90013032          Vinhos Tintos Importados       10024278
#
#                                     NOMEPRODUTO  TIPOFATURAMENTO  \
# ...

# %% [markdown]
# ### Tipos (DataFrame, Series)
#
# #### Series
# Coluna de uma Dataframe, se comporta semelhantemente a uma array. Além disso, quando chamado exibe as primeiras e últimas 5 linhas da coluna.
#
# #### DataFrame
# Uma planilha inteira num tipo Python.

# %%
series = vendas_db["CODIGOCLIENTE"]
series
# Out:
# 0        10000449
# 1        10000449
# 2        10000449
# 3        10000449
# 4        10000449
#            ...
# 40616    10005002
# 40617    10005002
# 40618    10005002
# 40619    10005002
# 40620    10005002
# Name: CODIGOCLIENTE, Length: 40621, dtype: int64

# %%
dataframe = vendas_db[["CODIGOCLIENTE"]]
dataframe
# Out:
#        CODIGOCLIENTE
# 0           10000449
# 1           10000449
# 2           10000449
# 3           10000449
# 4           10000449
# ...              ...
# 40616       10005002
# 40617       10005002
# 40618       10005002
# 40619       10005002
# 40620       10005002
#
# [40621 rows x 1 columns]

# %% [markdown]
# ### Funções/Atributos úteis
#
# #### Columns
# Autoexplicativo.
#
# #### Dtypes
# Tipagem de cada coluna.
#
# #### Info
# Como o anterior, mas mais alguns detalhes.
#
# #### Describe
# Exibe alguns dados úteis como média, min, max etc.

# %%
# vendas_db.columns
# vendas_db.dtypes
# vendas_db.info()
vendas_db.describe()
# Out:
#                       DATAEMISSAO  CODIGOCLIENTE  CODIGOGRUPOPRODUTO  \
# count                       40621   4.062100e+04        4.062100e+04
# mean   2026-02-14 19:14:50.583688   1.000386e+07        9.030686e+07
# min           2026-02-01 00:00:00   1.000045e+07        9.001300e+07
# 25%           2026-02-08 00:00:00   1.000400e+07        9.001306e+07
# 50%           2026-02-15 00:00:00   1.000421e+07        9.001316e+07
# 75%           2026-02-22 00:00:00   1.000423e+07        9.001317e+07
# max           2026-02-28 00:00:00   1.000500e+07        9.150341e+07
# std                           NaN   9.718213e+02        5.928791e+05
#
#        CODIGOPRODUTO  TIPOFATURAMENTO        VOLUME  VALORLIQUIDO
# count   4.062100e+04     40621.000000  40621.000000  4.062100e+04
# mean    1.039773e+07         1.414810     31.207700  3.136858e+03
# min     1.000116e+07         1.000000   -300.000000 -1.851525e+04
# 25%     1.000778e+07         1.000000      2.000000  3.202900e+02
# ...
